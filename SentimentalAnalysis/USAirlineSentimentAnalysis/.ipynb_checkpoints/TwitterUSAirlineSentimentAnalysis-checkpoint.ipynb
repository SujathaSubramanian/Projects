# %% [markdown]
# # Sentiment Analysis using Recurrent Neural Network
#
# When parsing Text Data remembering information long enough and to understand the context, is of paramount importance.Recurrent neural networks address this issue. They are networks with loops in them, allowing information to persist for a long period of time.However RNNs fail to learn, how long to remember information and how to learn new context. LSTMs(Long Short Term Memory)networks are a special kind of RNN, capable of learning long-term dependencies using a fundamental concept called  "cell state".Excellent blog on LSTM can be found here http://colah.github.io/posts/2015-08-Understanding-LSTMs/
#
# We will use a Kaggle Dataset (https://www.kaggle.com/crowdflower/twitter-airline-sentiment) for analyzing sentiments on US Airline Twitter Data.The model will be trained using LSTMs in TensorFlow.

# %%
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas
from sklearn.model_selection import train_test_split
import numpy
import re
import nltk
from nltk.corpus import stopwords
import numpy as np
import tensorflow as tf

# %%
Tweet = pandas.read_csv("Tweets.csv")

# %% [markdown]
# ## Data preprocessing
#
# Pre-process the data by keeping only the text data(without special characters),removing stop words and extracting only meaningful words. Once the data is clean, build the word corpus based on the given data

# %%
def tweet_to_words(raw_tweet):
    letters_only = re.sub("[^a-zA-Z@]", " ",raw_tweet) 
    words = letters_only.lower().split()                             
    stops = set(stopwords.words("english"))  
    meaningful_words = [w for w in words if not w in stops and not re.match("^[@]", w) and not re.match("flight",w)] 
    return( " ".join( meaningful_words ))

# %%
#Pre-process the tweet and store in a separate column
Tweet['clean_tweet']=Tweet['text'].apply(lambda x: tweet_to_words(x))
#Convert sentiment to binary
Tweet['sentiment'] = Tweet['airline_sentiment'].apply(lambda x: 0 if x == 'negative' else 1)

#Join all the words in review to build a corpus
all_text = ' '.join(Tweet['clean_tweet'])
words = all_text.split()

# Convert words to integers
from collections import Counter
counts = Counter(words)
vocab = sorted(counts, key=counts.get, reverse=True)
vocab_to_int = {word: ii for ii, word in enumerate(vocab, 1)}

tweet_ints = []
for each in Tweet['clean_tweet']:
    tweet_ints.append([vocab_to_int[word] for word in each.split()])

#Create a list of labels 
labels = np.array([0 if each == 'negative' else 1 for each in Tweet['airline_sentiment'][:]]) 

#Find the number of tweets with zero length after the data pre-processing
tweet_len = Counter([len(x) for x in tweet_ints])
print("Zero-length reviews: {}".format(tweet_len[0]))
print("Maximum review length: {}".format(max(tweet_len)))

#Remove those tweets with zero length and its correspoding label 
tweet_idx  = [idx for idx,tweet in enumerate(tweet_ints) if len(tweet) > 0]
labels = labels[tweet_idx]
Tweet = Tweet.ix[tweet_idx]
tweet_ints = [tweet for tweet in tweet_ints if len(tweet) > 0]

# %% [markdown]
# Create a feature matrix such that integers are arranged from right to left with leading zeroes.

# %%
seq_len = max(tweet_len)
features = np.zeros((len(tweet_ints), seq_len), dtype=int)
for i, row in enumerate(tweet_ints):
    features[i, -len(row):] = np.array(row)[:seq_len]

# %% [markdown]
# ## Training, Validation, Test

# %% [markdown]
# Split the data into training, validation, and test sets.

# %%
split_frac = 0.8
split_idx = int(len(features)*0.8)
train_x, val_x = features[:split_idx], features[split_idx:]
train_y, val_y = labels[:split_idx], labels[split_idx:]

test_idx = int(len(val_x)*0.5)
val_x, test_x = val_x[:test_idx], val_x[test_idx:]
val_y, test_y = val_y[:test_idx], val_y[test_idx:]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))

print("Train set: \t\t{}".format(train_y.shape), 
      "\nValidation set: \t{}".format(val_y.shape),
      "\nTest set: \t\t{}".format(test_y.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(11684, 22)
# Validation set: 	(1461, 22)
# Test set: 		(1461, 22)
# Train set: 		(11684,)
# Validation set: 	(1461,)
# Test set: 		(1461,)

# %% [markdown]
# ## Build the graph
#
# ### Define Hyper-Parameters
#
# lstm_size - Number of units in the hidden layers in the LSTM cells
# lstm_layers - Number of LSTM layers in the network. Start with 1, then add more if underfitting
# batch_size- The number of tweets to feed the network in one training pass. Typically this should be set as high as you can go without running out of memory.
# learning_rate: Learning rate
#
# ### Perform Embedding
# Converting words to the continuous vector space
#
# ### Build the LSTM cells
# Using the hyper paramter lstm_size,lstm_layers LSTM cells are added to he graph
#
# ### Training and validation in batches
# Once the graph is defined, training can be done in batches based on the batch_size hyper parameter.Models trains to improve the accuracy of the prediction.

# %%
lstm_size = 256
lstm_layers = 1
batch_size = 100
learning_rate = 0.001

# %%
#Create input placeholders
n_words = len(vocab_to_int)
# Create the graph object
graph = tf.Graph()
# Add nodes to the graph
with graph.as_default():
    inputs_ = tf.placeholder(tf.int32, [None, None], name='inputs')
    labels_ = tf.placeholder(tf.int32, [None, None], name='labels')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
# Embedding - Efficient way to process the input vector is to do embedding instead of one-hot encoding
# Size of the embedding vectors (number of units in the embedding layer)
embed_size = 300 

with graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs_)
    
#Build the LSTM cells
with graph.as_default():
    # Your basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    
    # Add dropout to the cell
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([drop] * lstm_layers)
    
    # Getting an initial state of all zeros
    initial_state = cell.zero_state(batch_size, tf.float32)

#RNN Forward pass
with graph.as_default():
    outputs, final_state = tf.nn.dynamic_rnn(cell, embed,
                                             initial_state=initial_state)
    
### Output - Final output of the RNN layer will be used for sentiment prediction. 
### So we need to grab the last output with `outputs[:, -1]`, the calculate the cost from that and `labels_`.
with graph.as_default():
    predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)
    cost = tf.losses.mean_squared_error(labels_, predictions)
    
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    
## Graph for checking Validation accuracy
with graph.as_default():
    correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
### Batching - Pick only full batches of data and return based on the batch_size
def get_batches(x, y, batch_size=100):
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %% [markdown]
# ## Training

# %%
epochs = 10

with graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    for e in range(epochs):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: 0.5,
                    initial_state: state}
            loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)
            
            if iteration%5==0:
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Train loss: {:.3f}".format(loss))

            if iteration%25==0:
                val_acc = []
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                for x, y in get_batches(val_x, val_y, batch_size):
                    feed = {inputs_: x,
                            labels_: y[:, None],
                            keep_prob: 1,
                            initial_state: val_state}
                    batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                    val_acc.append(batch_acc)
                print("Val acc: {:.3f}".format(np.mean(val_acc)))
            iteration +=1
    saver.save(sess, "checkpoints/twitter_sentiment.ckpt")
# Out:
# Epoch: 0/10 Iteration: 5 Train loss: 0.177
# Epoch: 0/10 Iteration: 10 Train loss: 0.217
# Epoch: 0/10 Iteration: 15 Train loss: 0.133
# Epoch: 0/10 Iteration: 20 Train loss: 0.147
# Epoch: 0/10 Iteration: 25 Train loss: 0.165
# Val acc: 0.727
# Epoch: 0/10 Iteration: 30 Train loss: 0.190
# Epoch: 0/10 Iteration: 35 Train loss: 0.194
# Epoch: 0/10 Iteration: 40 Train loss: 0.159
# Epoch: 0/10 Iteration: 45 Train loss: 0.219
# Epoch: 0/10 Iteration: 50 Train loss: 0.228
# Val acc: 0.611
# Epoch: 0/10 Iteration: 55 Train loss: 0.235
# Epoch: 0/10 Iteration: 60 Train loss: 0.189
# Epoch: 0/10 Iteration: 65 Train loss: 0.237
# Epoch: 0/10 Iteration: 70 Train loss: 0.158
# Epoch: 0/10 Iteration: 75 Train loss: 0.175
# Val acc: 0.747
# Epoch: 0/10 Iteration: 80 Train loss: 0.176
# Epoch: 0/10 Iteration: 85 Train loss: 0.197
# Epoch: 0/10 Iteration: 90 Train loss: 0.177
# Epoch: 0/10 Iteration: 95 Train loss: 0.135
# Epoch: 0/10 Iteration: 100 Train loss: 0.121
# Val acc: 0.776
# Epoch: 0/10 Iteration: 105 Train loss: 0.217
# Epoch: 0/10 Iteration: 110 Train loss: 0.099
# Epoch: 0/10 Iteration: 115 Train loss: 0.132
# Epoch: 1/10 Iteration: 120 Train loss: 0.195
# Epoch: 1/10 Iteration: 125 Train loss: 0.164
# Val acc: 0.742
# Epoch: 1/10 Iteration: 130 Train loss: 0.127
# Epoch: 1/10 Iteration: 135 Train loss: 0.120
# Epoch: 1/10 Iteration: 140 Train loss: 0.146
# Epoch: 1/10 Iteration: 145 Train loss: 0.137
# Epoch: 1/10 Iteration: 150 Train loss: 0.163
# Val acc: 0.796
# Epoch: 1/10 Iteration: 155 Train loss: 0.147
# Epoch: 1/10 Iteration: 160 Train loss: 0.092
# Epoch: 1/10 Iteration: 165 Train loss: 0.126
# Epoch: 1/10 Iteration: 170 Train loss: 0.087
# Epoch: 1/10 Iteration: 175 Train loss: 0.106
# Val acc: 0.772
# Epoch: 1/10 Iteration: 180 Train loss: 0.107
# Epoch: 1/10 Iteration: 185 Train loss: 0.141
# Epoch: 1/10 Iteration: 190 Train loss: 0.194
# Epoch: 1/10 Iteration: 195 Train loss: 0.127
# Epoch: 1/10 Iteration: 200 Train loss: 0.098
# Val acc: 0.795
# Epoch: 1/10 Iteration: 205 Train loss: 0.123
# Epoch: 1/10 Iteration: 210 Train loss: 0.147
# Epoch: 1/10 Iteration: 215 Train loss: 0.074
# Epoch: 1/10 Iteration: 220 Train loss: 0.066
# Epoch: 1/10 Iteration: 225 Train loss: 0.075
# Val acc: 0.800
# Epoch: 1/10 Iteration: 230 Train loss: 0.088
# Epoch: 2/10 Iteration: 235 Train loss: 0.134
# Epoch: 2/10 Iteration: 240 Train loss: 0.107
# Epoch: 2/10 Iteration: 245 Train loss: 0.106
# Epoch: 2/10 Iteration: 250 Train loss: 0.097
# Val acc: 0.798
# Epoch: 2/10 Iteration: 255 Train loss: 0.099
# Epoch: 2/10 Iteration: 260 Train loss: 0.101
# Epoch: 2/10 Iteration: 265 Train loss: 0.086
# Epoch: 2/10 Iteration: 270 Train loss: 0.090
# Epoch: 2/10 Iteration: 275 Train loss: 0.130
# Val acc: 0.794
# Epoch: 2/10 Iteration: 280 Train loss: 0.090
# Epoch: 2/10 Iteration: 285 Train loss: 0.103
# Epoch: 2/10 Iteration: 290 Train loss: 0.077
# Epoch: 2/10 Iteration: 295 Train loss: 0.072
# Epoch: 2/10 Iteration: 300 Train loss: 0.082
# Val acc: 0.786
# Epoch: 2/10 Iteration: 305 Train loss: 0.090
# Epoch: 2/10 Iteration: 310 Train loss: 0.099
# Epoch: 2/10 Iteration: 315 Train loss: 0.118
# Epoch: 2/10 Iteration: 320 Train loss: 0.079
# Epoch: 2/10 Iteration: 325 Train loss: 0.079
# Val acc: 0.773
# Epoch: 2/10 Iteration: 330 Train loss: 0.084
# Epoch: 2/10 Iteration: 335 Train loss: 0.029
# Epoch: 2/10 Iteration: 340 Train loss: 0.087
# Epoch: 2/10 Iteration: 345 Train loss: 0.102
# Epoch: 3/10 Iteration: 350 Train loss: 0.082
# Val acc: 0.807
# Epoch: 3/10 Iteration: 355 Train loss: 0.093
# Epoch: 3/10 Iteration: 360 Train loss: 0.063
# Epoch: 3/10 Iteration: 365 Train loss: 0.110
# Epoch: 3/10 Iteration: 370 Train loss: 0.071
# Epoch: 3/10 Iteration: 375 Train loss: 0.084
# Val acc: 0.805
# Epoch: 3/10 Iteration: 380 Train loss: 0.088
# Epoch: 3/10 Iteration: 385 Train loss: 0.108
# Epoch: 3/10 Iteration: 390 Train loss: 0.076
# Epoch: 3/10 Iteration: 395 Train loss: 0.092
# Epoch: 3/10 Iteration: 400 Train loss: 0.045
# Val acc: 0.783
# Epoch: 3/10 Iteration: 405 Train loss: 0.079
# Epoch: 3/10 Iteration: 410 Train loss: 0.055
# Epoch: 3/10 Iteration: 415 Train loss: 0.058
# Epoch: 3/10 Iteration: 420 Train loss: 0.074
# Epoch: 3/10 Iteration: 425 Train loss: 0.059
# Val acc: 0.789
# Epoch: 3/10 Iteration: 430 Train loss: 0.056
# Epoch: 3/10 Iteration: 435 Train loss: 0.051
# Epoch: 3/10 Iteration: 440 Train loss: 0.057
# Epoch: 3/10 Iteration: 445 Train loss: 0.035
# Epoch: 3/10 Iteration: 450 Train loss: 0.039
# Val acc: 0.781
# Epoch: 3/10 Iteration: 455 Train loss: 0.067
# Epoch: 3/10 Iteration: 460 Train loss: 0.062
# Epoch: 4/10 Iteration: 465 Train loss: 0.058
# Epoch: 4/10 Iteration: 470 Train loss: 0.054
# Epoch: 4/10 Iteration: 475 Train loss: 0.023
# Val acc: 0.789
# Epoch: 4/10 Iteration: 480 Train loss: 0.061
# Epoch: 4/10 Iteration: 485 Train loss: 0.067
# Epoch: 4/10 Iteration: 490 Train loss: 0.035
# Epoch: 4/10 Iteration: 495 Train loss: 0.033
# Epoch: 4/10 Iteration: 500 Train loss: 0.045
# Val acc: 0.796
# Epoch: 4/10 Iteration: 505 Train loss: 0.068
# Epoch: 4/10 Iteration: 510 Train loss: 0.038
# Epoch: 4/10 Iteration: 515 Train loss: 0.057
# Epoch: 4/10 Iteration: 520 Train loss: 0.062
# Epoch: 4/10 Iteration: 525 Train loss: 0.026
# Val acc: 0.762
# Epoch: 4/10 Iteration: 530 Train loss: 0.045
# Epoch: 4/10 Iteration: 535 Train loss: 0.086
# Epoch: 4/10 Iteration: 540 Train loss: 0.065
# Epoch: 4/10 Iteration: 545 Train loss: 0.046
# Epoch: 4/10 Iteration: 550 Train loss: 0.042
# Val acc: 0.785
# Epoch: 4/10 Iteration: 555 Train loss: 0.115
# Epoch: 4/10 Iteration: 560 Train loss: 0.028
# Epoch: 4/10 Iteration: 565 Train loss: 0.044
# Epoch: 4/10 Iteration: 570 Train loss: 0.039
# Epoch: 4/10 Iteration: 575 Train loss: 0.028
# Val acc: 0.790
# Epoch: 4/10 Iteration: 580 Train loss: 0.055
# Epoch: 5/10 Iteration: 585 Train loss: 0.039
# Epoch: 5/10 Iteration: 590 Train loss: 0.029
# Epoch: 5/10 Iteration: 595 Train loss: 0.015
# Epoch: 5/10 Iteration: 600 Train loss: 0.043
# Val acc: 0.774
# Epoch: 5/10 Iteration: 605 Train loss: 0.039
# Epoch: 5/10 Iteration: 610 Train loss: 0.026
# Epoch: 5/10 Iteration: 615 Train loss: 0.040
# Epoch: 5/10 Iteration: 620 Train loss: 0.048
# Epoch: 5/10 Iteration: 625 Train loss: 0.041
# Val acc: 0.793
# Epoch: 5/10 Iteration: 630 Train loss: 0.057
# Epoch: 5/10 Iteration: 635 Train loss: 0.033
# Epoch: 5/10 Iteration: 640 Train loss: 0.040
# Epoch: 5/10 Iteration: 645 Train loss: 0.051
# Epoch: 5/10 Iteration: 650 Train loss: 0.034
# Val acc: 0.756
# Epoch: 5/10 Iteration: 655 Train loss: 0.020
# Epoch: 5/10 Iteration: 660 Train loss: 0.031
# Epoch: 5/10 Iteration: 665 Train loss: 0.035
# Epoch: 5/10 Iteration: 670 Train loss: 0.069
# Epoch: 5/10 Iteration: 675 Train loss: 0.037
# Val acc: 0.787
# Epoch: 5/10 Iteration: 680 Train loss: 0.031
# Epoch: 5/10 Iteration: 685 Train loss: 0.049
# Epoch: 5/10 Iteration: 690 Train loss: 0.020
# Epoch: 5/10 Iteration: 695 Train loss: 0.039
# Epoch: 6/10 Iteration: 700 Train loss: 0.037
# Val acc: 0.793
# Epoch: 6/10 Iteration: 705 Train loss: 0.047
# Epoch: 6/10 Iteration: 710 Train loss: 0.008
# Epoch: 6/10 Iteration: 715 Train loss: 0.039
# Epoch: 6/10 Iteration: 720 Train loss: 0.014
# Epoch: 6/10 Iteration: 725 Train loss: 0.043
# Val acc: 0.776
# Epoch: 6/10 Iteration: 730 Train loss: 0.043
# Epoch: 6/10 Iteration: 735 Train loss: 0.007
# Epoch: 6/10 Iteration: 740 Train loss: 0.026
# Epoch: 6/10 Iteration: 745 Train loss: 0.024
# Epoch: 6/10 Iteration: 750 Train loss: 0.030
# Val acc: 0.800
# Epoch: 6/10 Iteration: 755 Train loss: 0.020
# Epoch: 6/10 Iteration: 760 Train loss: 0.046
# Epoch: 6/10 Iteration: 765 Train loss: 0.014
# Epoch: 6/10 Iteration: 770 Train loss: 0.051
# Epoch: 6/10 Iteration: 775 Train loss: 0.020
# Val acc: 0.762
# Epoch: 6/10 Iteration: 780 Train loss: 0.004
# Epoch: 6/10 Iteration: 785 Train loss: 0.044
# Epoch: 6/10 Iteration: 790 Train loss: 0.029
# Epoch: 6/10 Iteration: 795 Train loss: 0.017
# Epoch: 6/10 Iteration: 800 Train loss: 0.003
# Val acc: 0.782
# Epoch: 6/10 Iteration: 805 Train loss: 0.022
# Epoch: 6/10 Iteration: 810 Train loss: 0.025
# Epoch: 7/10 Iteration: 815 Train loss: 0.027
# Epoch: 7/10 Iteration: 820 Train loss: 0.038
# Epoch: 7/10 Iteration: 825 Train loss: 0.022
# Val acc: 0.790
# Epoch: 7/10 Iteration: 830 Train loss: 0.023
# Epoch: 7/10 Iteration: 835 Train loss: 0.029
# Epoch: 7/10 Iteration: 840 Train loss: 0.038
# Epoch: 7/10 Iteration: 845 Train loss: 0.006
# Epoch: 7/10 Iteration: 850 Train loss: 0.026
# Val acc: 0.776
# Epoch: 7/10 Iteration: 855 Train loss: 0.052
# Epoch: 7/10 Iteration: 860 Train loss: 0.011
# Epoch: 7/10 Iteration: 865 Train loss: 0.032
# Epoch: 7/10 Iteration: 870 Train loss: 0.007
# Epoch: 7/10 Iteration: 875 Train loss: 0.004
# Val acc: 0.784
# Epoch: 7/10 Iteration: 880 Train loss: 0.019
# Epoch: 7/10 Iteration: 885 Train loss: 0.021
# Epoch: 7/10 Iteration: 890 Train loss: 0.023
# Epoch: 7/10 Iteration: 895 Train loss: 0.032
# Epoch: 7/10 Iteration: 900 Train loss: 0.015
# Val acc: 0.758
# Epoch: 7/10 Iteration: 905 Train loss: 0.004
# Epoch: 7/10 Iteration: 910 Train loss: 0.021
# Epoch: 7/10 Iteration: 915 Train loss: 0.003
# Epoch: 7/10 Iteration: 920 Train loss: 0.025
# Epoch: 7/10 Iteration: 925 Train loss: 0.037
# Val acc: 0.787
# Epoch: 8/10 Iteration: 930 Train loss: 0.030
# Epoch: 8/10 Iteration: 935 Train loss: 0.014
# Epoch: 8/10 Iteration: 940 Train loss: 0.028
# Epoch: 8/10 Iteration: 945 Train loss: 0.025
# Epoch: 8/10 Iteration: 950 Train loss: 0.024
# Val acc: 0.784
# Epoch: 8/10 Iteration: 955 Train loss: 0.023
# Epoch: 8/10 Iteration: 960 Train loss: 0.007
# Epoch: 8/10 Iteration: 965 Train loss: 0.038
# Epoch: 8/10 Iteration: 970 Train loss: 0.010
# Epoch: 8/10 Iteration: 975 Train loss: 0.025
# Val acc: 0.776
# Epoch: 8/10 Iteration: 980 Train loss: 0.009
# Epoch: 8/10 Iteration: 985 Train loss: 0.008
# Epoch: 8/10 Iteration: 990 Train loss: 0.012
# Epoch: 8/10 Iteration: 995 Train loss: 0.005
# Epoch: 8/10 Iteration: 1000 Train loss: 0.018
# Val acc: 0.776
# Epoch: 8/10 Iteration: 1005 Train loss: 0.011
# Epoch: 8/10 Iteration: 1010 Train loss: 0.008
# Epoch: 8/10 Iteration: 1015 Train loss: 0.025
# Epoch: 8/10 Iteration: 1020 Train loss: 0.011
# Epoch: 8/10 Iteration: 1025 Train loss: 0.002
# Val acc: 0.775
# Epoch: 8/10 Iteration: 1030 Train loss: 0.012
# Epoch: 8/10 Iteration: 1035 Train loss: 0.023
# Epoch: 8/10 Iteration: 1040 Train loss: 0.002
# Epoch: 9/10 Iteration: 1045 Train loss: 0.007
# Epoch: 9/10 Iteration: 1050 Train loss: 0.026
# Val acc: 0.786
# Epoch: 9/10 Iteration: 1055 Train loss: 0.001
# Epoch: 9/10 Iteration: 1060 Train loss: 0.018
# Epoch: 9/10 Iteration: 1065 Train loss: 0.032
# Epoch: 9/10 Iteration: 1070 Train loss: 0.003
# Epoch: 9/10 Iteration: 1075 Train loss: 0.002
# Val acc: 0.791
# Epoch: 9/10 Iteration: 1080 Train loss: 0.018
# Epoch: 9/10 Iteration: 1085 Train loss: 0.017
# Epoch: 9/10 Iteration: 1090 Train loss: 0.012
# Epoch: 9/10 Iteration: 1095 Train loss: 0.021
# Epoch: 9/10 Iteration: 1100 Train loss: 0.001
# Val acc: 0.789
# Epoch: 9/10 Iteration: 1105 Train loss: 0.007
# Epoch: 9/10 Iteration: 1110 Train loss: 0.020
# Epoch: 9/10 Iteration: 1115 Train loss: 0.003
# Epoch: 9/10 Iteration: 1120 Train loss: 0.028
# Epoch: 9/10 Iteration: 1125 Train loss: 0.025
# Val acc: 0.781
# Epoch: 9/10 Iteration: 1130 Train loss: 0.013
# Epoch: 9/10 Iteration: 1135 Train loss: 0.044
# Epoch: 9/10 Iteration: 1140 Train loss: 0.013
# Epoch: 9/10 Iteration: 1145 Train loss: 0.037
# Epoch: 9/10 Iteration: 1150 Train loss: 0.011
# Val acc: 0.783
# Epoch: 9/10 Iteration: 1155 Train loss: 0.018
# Epoch: 9/10 Iteration: 1160 Train loss: 0.035

# %% [markdown]
# ## Testing
# For the tweets in test set, predict the sentiment using the trained model

# %%
test_acc = []
test_pred = []
with tf.Session(graph=graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {inputs_: x,
                labels_: y[:, None],
                keep_prob: 1,
                initial_state: test_state}
        batch_acc, test_state= sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
        prediction = tf.cast(tf.round(predictions),tf.int32)
        prediction = sess.run(prediction,feed_dict=feed)
        test_pred.append(prediction)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))
# Out:
# Test accuracy: 0.838

# %%
##Use the tweet sentiment predicted for the data in the test set,for plotting the wordcloud
test_pred_flat = (np.array(test_pred)).flatten()
start_idx = len(train_x) + len(val_x)
end_idx = start_idx + len(test_pred_flat)+1
Tweet.loc[start_idx:end_idx,'predicted_sentiment'] = test_pred_flat

# %% [markdown]
# ## Word Cloud Visualization
#
# For all the tweets in test set, split into positive and negative tweets.For the postive tweets, compare with the tweets that are predicted as positive using WordCloud. Similary, for the negative tweets compare with the tweets that are predicted as negative using WordCloud.

# %%
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt

##Find all the tweets with actual sentiment as "Positive"
start_idx = len(train_x) + len(val_x)
test_tweets = Tweet[start_idx:]

fig = plt.figure( figsize=(40,40))
sub1= fig.add_subplot(2,2,1)

posActualTweets = test_tweets[test_tweets.sentiment==1]
posPredTweets = test_tweets[test_tweets.predicted_sentiment==1]

tweetText = ' '.join((posActualTweets['clean_tweet']))
# Generate a word cloud image
wordcloud = WordCloud().generate(tweetText)
plt.title("Positive Sentiment - Actual")
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

sub2= fig.add_subplot(2,2,2)
plt.title("Positive Sentiment - Prediction")

tweetText = ' '.join((posPredTweets['clean_tweet']))
wordcloud = WordCloud().generate(tweetText)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
negActualTweets = test_tweets[test_tweets.sentiment!=1]
negPredTweets = test_tweets[test_tweets.predicted_sentiment!=1]

tweetText = ' '.join((negActualTweets['clean_tweet']))

fig = plt.figure( figsize=(20,20))
sub1= fig.add_subplot(2,2,1)
# Generate a word cloud image
wordcloud = WordCloud().generate(tweetText)
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("Negative Sentiment - Actual")
plt.axis("off")

sub2= fig.add_subplot(2,2,2)
tweetText = ' '.join((negPredTweets['clean_tweet']))
wordcloud = WordCloud().generate(tweetText)
plt.title("Negative Sentiment - Prediction")
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Conclusion
# Model achieved a test accuracy of .838. By looking at the word cloud, for postive and negative tweets the current model appears to be more closely predicting negative tweets than positive tweets.
